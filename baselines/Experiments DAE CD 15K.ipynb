# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/Shareddrives/Anomaly/
# Out:
# /content/gdrive/Shareddrives/Anomaly

# %%
import pandas as pd
import numpy as np
from sklearn.utils import resample

# %%
train_df = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/TRAIN_FINAL_CROSS_DOM_15K.csv')

# %%
train_df.head()
# Out:
#    Fwd Pkt Len Max  Fwd Pkt Len Min  Fwd Pkt Len Mean  Fwd Pkt Len Std  \
# 0        -0.632694        -0.580092         -0.881051        -0.598698
# 1        -0.712442         1.429695         -0.374214        -0.852608
# 2        -0.632694        -0.580092         -0.881051        -0.598698
# 3        -0.512219         0.741109         -0.261913        -0.598698
# 4         1.709488        -0.580092          1.686548         1.800385
#
#    Bwd Pkt Len Max  Bwd Pkt Len Min  Bwd Pkt Len Mean  Bwd Pkt Len Std  \
# 0        -0.686276        -0.635757         -0.698694        -0.588015
# 1        -0.536097         3.273131          0.201001        -0.794297
# 2        -0.686276        -0.635757         -0.698694        -0.588015
# 3        -0.468995         1.592125         -0.091600        -0.588015
# 4         1.352691        -0.635757         -0.000646         0.862475
#
#    Flow Byts/s  Flow Pkts/s  ...  Pkt Len Std  Pkt Len Var  Pkt Size Avg  \
# 0    -0.085003     0.369437  ...    -0.694505    -0.517268     -0.835366
# 1    -0.068330    -0.136598  ...    -0.490374    -0.598422      0.082195
# 2    -0.085003    -0.164555  ...    -0.694505    -0.517268     -0.835366
# 3    -0.081888    -0.163937  ...    -0.416409    -0.490281     -0.084858
# 4    -0.084752    -0.164529  ...     0.844407     0.309143      0.273510
#
#    Fwd Seg Size Avg  Bwd Seg Size Avg  Init Fwd Win Byts  Init Bwd Win Byts  \
# 0         -0.881051         -0.698694           0.130146          -0.314942
# 1         -0.374214          0.201001          -0.755270          -0.426041
# 2         -0.881051         -0.698694          -0.468538          -0.314942
# 3         -0.261913         -0.091600          -0.468538          -0.314942
# 4          1.686548         -0.000646           0.481678           4.010477
#
#    Fwd Seg Size Min  Idle Min  Label
# 0          0.680731 -0.344192    0.0
# 1         -1.445423 -0.361189    0.0
# 2         -2.426335  1.906829    0.0
# 3         -1.183509 -0.344192    0.0
# 4          0.680731 -0.344192    0.0
#
# [5 rows x 30 columns]

# %%
X_train = train_df.drop(labels = ['Label'], axis=1)

# %%
X_train.head()
# Out:
#    Fwd Pkt Len Max  Fwd Pkt Len Min  Fwd Pkt Len Mean  Fwd Pkt Len Std  \
# 0        -0.632694        -0.580092         -0.881051        -0.598698
# 1        -0.712442         1.429695         -0.374214        -0.852608
# 2        -0.632694        -0.580092         -0.881051        -0.598698
# 3        -0.512219         0.741109         -0.261913        -0.598698
# 4         1.709488        -0.580092          1.686548         1.800385
#
#    Bwd Pkt Len Max  Bwd Pkt Len Min  Bwd Pkt Len Mean  Bwd Pkt Len Std  \
# 0        -0.686276        -0.635757         -0.698694        -0.588015
# 1        -0.536097         3.273131          0.201001        -0.794297
# 2        -0.686276        -0.635757         -0.698694        -0.588015
# 3        -0.468995         1.592125         -0.091600        -0.588015
# 4         1.352691        -0.635757         -0.000646         0.862475
#
#    Flow Byts/s  Flow Pkts/s  ...  Pkt Len Mean  Pkt Len Std  Pkt Len Var  \
# 0    -0.085003     0.369437  ...     -0.745314    -0.694505    -0.517268
# 1    -0.068330    -0.136598  ...     -0.019745    -0.490374    -0.598422
# 2    -0.085003    -0.164555  ...     -0.745314    -0.694505    -0.517268
# 3    -0.081888    -0.163937  ...     -0.231251    -0.416409    -0.490281
# 4    -0.084752    -0.164529  ...      0.337016     0.844407     0.309143
#
#    Pkt Size Avg  Fwd Seg Size Avg  Bwd Seg Size Avg  Init Fwd Win Byts  \
# 0     -0.835366         -0.881051         -0.698694           0.130146
# 1      0.082195         -0.374214          0.201001          -0.755270
# 2     -0.835366         -0.881051         -0.698694          -0.468538
# 3     -0.084858         -0.261913         -0.091600          -0.468538
# 4      0.273510          1.686548         -0.000646           0.481678
#
#    Init Bwd Win Byts  Fwd Seg Size Min  Idle Min
# 0          -0.314942          0.680731 -0.344192
# 1          -0.426041         -1.445423 -0.361189
# 2          -0.314942         -2.426335  1.906829
# 3          -0.314942         -1.183509 -0.344192
# 4           4.010477          0.680731 -0.344192
#
# [5 rows x 29 columns]

# %%
X_train.shape
# Out:
# (156903, 29)

# %%
X_train = X_train.to_numpy()

# %%
y_train = train_df['Label']

# %%
y_train.value_counts()
# Out:
# 0.0    97826
# 1.0    59077
# Name: Label, dtype: int64

# %%
y_train[y_train>1.0]=1.0

# %%
y_train = y_train.to_numpy()

# %%
y_train.shape
# Out:
# (156903,)

# %%
y_train_0 = y_train[y_train == 0]

# %%
y_train_1 = y_train[y_train == 1]

# %%
print(y_train_0.shape, y_train_1.shape)
# Out:
# (97826,) (59077,)

# %%
X_train_0 = X_train[y_train == 0]

# %%
X_train_1 = X_train[y_train == 1]

# %%
print(X_train_0.shape, X_train_1.shape)
# Out:
# (97826, 29) (59077, 29)

# %%
X_train_0, y_train_0, X_train_1, y_train_1 = X_train_0[0:90000], y_train_0[0:90000], X_train_1[0:50000], y_train_1[0:50000]

# %%
y_train = np.concatenate((y_train_0, y_train_1))

# %%
print(X_train_0.shape, X_train_1.shape)
# Out:
# (90000, 29) (50000, 29)

# %%
X_train = np.concatenate((X_train_0, X_train_1))

# %%
print(X_train.shape, y_train.shape)
# Out:
# (140000, 29) (140000,)

# %%
Xo_train = np.concatenate((X_train_0, X_train_0[0:50000]))

# %%
print(Xo_train.shape)
# Out:
# (140000, 29)

# %%
BOT_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/BOT.csv')

# %%
BOT_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_BOT_test = BOT_test.drop(labels = ['Label'], axis=1)

# %%
X_BOT_test = X_BOT_test.to_numpy()

# %%
y_BOT_test = BOT_test['Label']

# %%
y_BOT_test.value_counts()
# Out:
# 1.0    10000
# Name: Label, dtype: int64

# %%
y_BOT_test[y_BOT_test>1.0] = 1.0

# %%
y_BOT_test = y_BOT_test.to_numpy()

# %%
RARE_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/RARE.csv')

# %%
RARE_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_RARE_test = RARE_test.drop(labels = ['Label'], axis=1)

# %%
X_RARE_test = X_RARE_test.to_numpy()

# %%
y_RARE_test = RARE_test['Label']

# %%
y_RARE_test.value_counts()
# Out:
# 1.0    566
# Name: Label, dtype: int64

# %%
y_RARE_test[y_RARE_test>1.0] = 1.0

# %%
y_RARE_test = y_RARE_test.to_numpy()

# %%
SlowHTTPTest_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/SlowHTTPTest.csv')

# %%
SlowHTTPTest_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_SlowHTTPTest_test = SlowHTTPTest_test.drop(labels = ['Label'], axis=1)

# %%
X_SlowHTTPTest_test = X_SlowHTTPTest_test.to_numpy()

# %%
y_SlowHTTPTest_test = SlowHTTPTest_test['Label']

# %%
y_SlowHTTPTest_test.value_counts()
# Out:
# 1.0    461912
# Name: Label, dtype: int64

# %%
y_SlowHTTPTest_test[y_SlowHTTPTest_test>1.0] = 1.0

# %%
y_SlowHTTPTest_test = y_SlowHTTPTest_test.to_numpy()

# %%
DDOS_SOLARIS_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/DDOS_SOLARIS.csv')

# %%
DDOS_SOLARIS_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_DDOS_SOLARIS_test = DDOS_SOLARIS_test.drop(labels = ['Label'], axis=1)

# %%
X_DDOS_SOLARIS_test = X_DDOS_SOLARIS_test.to_numpy()

# %%
y_DDOS_SOLARIS_test = DDOS_SOLARIS_test['Label']

# %%
y_DDOS_SOLARIS_test.value_counts()
# Out:
# 1.0    10990
# Name: Label, dtype: int64

# %%
y_DDOS_SOLARIS_test[y_DDOS_SOLARIS_test>1.0] = 1.0

# %%
y_DDOS_SOLARIS_test = y_DDOS_SOLARIS_test.to_numpy()

# %%
DDOS_HOIC_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/DDOS_HOIC.csv')

# %%
DDOS_HOIC_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_DDOS_HOIC_test = DDOS_HOIC_test.drop(labels = ['Label'], axis=1)

# %%
X_DDOS_HOIC_test = X_DDOS_HOIC_test.to_numpy()

# %%
y_DDOS_HOIC_test = DDOS_HOIC_test['Label']

# %%
y_DDOS_HOIC_test.value_counts()
# Out:
# 1.0    686012
# Name: Label, dtype: int64

# %%
y_DDOS_HOIC_test[y_DDOS_HOIC_test>1.0] = 1.0

# %%
y_DDOS_HOIC_test = y_DDOS_HOIC_test.to_numpy()

# %%
DDOS_GOLDEN_EYE_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/DDOS_GOLDEN_EYE.csv')

# %%
DDOS_GOLDEN_EYE_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_DDOS_GOLDEN_EYE_test = DDOS_GOLDEN_EYE_test.drop(labels = ['Label'], axis=1)

# %%
X_DDOS_GOLDEN_EYE_test = X_DDOS_GOLDEN_EYE_test.to_numpy()

# %%
y_DDOS_GOLDEN_EYE_test = DDOS_GOLDEN_EYE_test['Label']

# %%
y_DDOS_GOLDEN_EYE_test.value_counts()
# Out:
# 1.0    41508
# Name: Label, dtype: int64

# %%
y_DDOS_GOLDEN_EYE_test[y_DDOS_GOLDEN_EYE_test>1.0] = 1.0

# %%
y_DDOS_GOLDEN_EYE_test = y_DDOS_GOLDEN_EYE_test.to_numpy()

# %%
OOD_INFIL_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/OOD_INFIL.csv')

# %%
OOD_INFIL_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_OOD_INFIL_test = OOD_INFIL_test.drop(labels = ['Label'], axis=1)

# %%
X_OOD_INFIL_test = X_OOD_INFIL_test.to_numpy()

# %%
y_OOD_INFIL_test = OOD_INFIL_test['Label']

# %%
y_OOD_INFIL_test.value_counts()
# Out:
# 1.0    49504
# Name: Label, dtype: int64

# %%
y_OOD_INFIL_test[y_OOD_INFIL_test>1.0] = 1.0

# %%
y_OOD_INFIL_test = y_OOD_INFIL_test.to_numpy()

# %%
BENIGN_TEST_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/BENIGN_TEST.csv')

# %%
BENIGN_TEST_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_BENIGN_TEST_test = BENIGN_TEST_test.drop(labels = ['Label'], axis=1)

# %%
X_BENIGN_TEST_test = X_BENIGN_TEST_test.to_numpy()

# %%
y_BENIGN_TEST_test = BENIGN_TEST_test['Label']

# %%
y_BENIGN_TEST_test.value_counts()
# Out:
# 0.0    9946
# Name: Label, dtype: int64

# %%
y_BENIGN_TEST_test[y_BENIGN_TEST_test>1.0] = 1.0

# %%
y_BENIGN_TEST_test = y_BENIGN_TEST_test.to_numpy()

# %%
from models.dae_svm import DAESVMModel
# from models.bigan import BiGANModel
# from models.seq2seq import Seq2SeqModel
from utils import eval_utils

# %%
ae_kwargs = {}
ae_kwargs["latent_dim"] = 7
ae_kwargs["hidden_layers"] = 2
ae_kwargs["hidden_dim"] = [20, 14]
ae_kwargs["epochs"] = 50
ae_kwargs["batch_size"] = 32
ae_kwargs["learning_rate"] = 0.001
ae_kwargs["output_activation"] = "relu"
# ae_kwargs["model_path"] = ae_model_path

# %%
aeknn = DAESVMModel(X_train.shape[1], **ae_kwargs)
aeknn.train(X_train, X_BENIGN_TEST_test, y_train, Xo_train)
#aeknn.save_model()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 29)]              0
#
#  encoder_hidden_0 (Dense)    (None, 20)                600
#
#  batch_normalization (Batch  (None, 20)                80
#  Normalization)
#
#  encoder_hidden_1 (Dense)    (None, 14)                294
#
#  batch_normalization_1 (Bat  (None, 14)                56
#  chNormalization)
#
#  z_ (Dense)                  (None, 7)                 105
#
# =================================================================
# Total params: 1135 (4.43 KB)
# Trainable params: 1067 (4.17 KB)
# Non-trainable params: 68 (272.00 Byte)
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_ (InputLayer)             [(None, 7)]               0
#
#  decoder_hidden_0 (Dense)    (None, 14)                112
#
#  batch_normalization_2 (Bat  (None, 14)                56
#  chNormalization)
#
#  decoder_hidden_1 (Dense)    (None, 20)                300
#
#  batch_normalization_3 (Bat  (None, 20)                80
#  chNormalization)
#
#  decoder_output (Dense)      (None, 29)                609
#
# =================================================================
# Total params: 1157 (4.52 KB)
# Trainable params: 1089 (4.25 KB)
# Non-trainable params: 68 (272.00 Byte)
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 4375/4375 [==============================] - 32s 6ms/step - loss: 0.6583 - val_loss: 0.4281
# Epoch 2/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5654 - val_loss: 0.3960
# Epoch 3/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5486 - val_loss: 0.4246
# Epoch 4/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5418 - val_loss: 0.4293
# Epoch 5/50
# 4375/4375 [==============================] - 25s 6ms/step - loss: 0.5380 - val_loss: 0.3819
# Epoch 6/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5372 - val_loss: 0.3285
# Epoch 7/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5340 - val_loss: 0.3325
# Epoch 8/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5320 - val_loss: 0.3459
# Epoch 9/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5305 - val_loss: 0.3619
# Epoch 10/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5290 - val_loss: 0.3635
# Epoch 11/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5280 - val_loss: 0.3621
# Epoch 12/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5270 - val_loss: 0.3886
# Epoch 13/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5269 - val_loss: 0.3460
# Epoch 14/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5259 - val_loss: 0.3377
# Epoch 15/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5254 - val_loss: 0.3286
# Epoch 16/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5259 - val_loss: 0.3233
# Epoch 17/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5248 - val_loss: 0.3294
# Epoch 18/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5244 - val_loss: 0.3120
# Epoch 19/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5240 - val_loss: 0.3337
# Epoch 20/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5246 - val_loss: 0.3540
# Epoch 21/50
# 4375/4375 [==============================] - 25s 6ms/step - loss: 0.5232 - val_loss: 0.3666
# Epoch 22/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5236 - val_loss: 0.3597
# Epoch 23/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5223 - val_loss: 0.3430
# Epoch 24/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5229 - val_loss: 0.3250
# Epoch 25/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5227 - val_loss: 0.3610
# Epoch 26/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5231 - val_loss: 0.3624
# Epoch 27/50
# 4375/4375 [==============================] - 25s 6ms/step - loss: 0.5221 - val_loss: 0.3134
# Epoch 28/50
# 4375/4375 [==============================] - 25s 6ms/step - loss: 0.5218 - val_loss: 0.3197
# Epoch 29/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5220 - val_loss: 0.3217
# Epoch 30/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5220 - val_loss: 0.3487
# Epoch 31/50
# 4375/4375 [==============================] - 25s 6ms/step - loss: 0.5214 - val_loss: 0.3622
# Epoch 32/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5215 - val_loss: 0.3614
# Epoch 33/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5212 - val_loss: 0.3390
# Epoch 34/50
# 4375/4375 [==============================] - 25s 6ms/step - loss: 0.5212 - val_loss: 0.3328
# Epoch 35/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5208 - val_loss: 0.3407
# Epoch 36/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5206 - val_loss: 0.3533
# Epoch 37/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5211 - val_loss: 0.3270
# Epoch 38/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5203 - val_loss: 0.3487
# Epoch 39/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5208 - val_loss: 0.3408
# Epoch 40/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5204 - val_loss: 0.3413
# Epoch 41/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5207 - val_loss: 0.3384
# Epoch 42/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5212 - val_loss: 0.3430
# Epoch 43/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5196 - val_loss: 0.3693
# Epoch 44/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5201 - val_loss: 0.3386
# Epoch 45/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5196 - val_loss: 0.4205
# Epoch 46/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5206 - val_loss: 0.3472
# Epoch 47/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5200 - val_loss: 0.3838
# Epoch 48/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5194 - val_loss: 0.3322
# Epoch 49/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5195 - val_loss: 0.3589
# Epoch 50/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5197 - val_loss: 0.3674

# %%
results_BOT = aeknn.compute_results(np.concatenate((X_BOT_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_BOT_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_BOT)
# Out:
# {'acc': 0.6547177378923092, 'precision': 0.7264658809835588, 'recall': 0.4993, 'f1': 0.5918331061459136, 'f2': 0.5326093913340303, 'roc': 0.6551396440780214}

# %%
results_RARE = aeknn.compute_results(np.concatenate((X_RARE_test[:566], X_BENIGN_TEST_test[:566])), np.concatenate((y_RARE_test[:566], y_BENIGN_TEST_test[:566])))
print(results_RARE)
# Out:
# {'acc': 0.523851590106007, 'precision': 0.5564853556485355, 'recall': 0.23498233215547704, 'f1': 0.3304347826086957, 'f2': 0.26568118258090295, 'roc': 0.523851590106007}

# %%
results_SlowHTTPTest = aeknn.compute_results(np.concatenate((X_SlowHTTPTest_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_SlowHTTPTest_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_SlowHTTPTest)
# Out:
# {'acc': 0.6489521708613256, 'precision': 0.7218111867416396, 'recall': 0.4878, 'f1': 0.5821697099892589, 'f2': 0.5216219684332093, 'roc': 0.6493896440780214}

# %%
results_DDOS_SOLARIS = aeknn.compute_results(np.concatenate((X_DDOS_SOLARIS_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_DDOS_SOLARIS_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_DDOS_SOLARIS)
# Out:
# {'acc': 0.5069688158026672, 'precision': 0.521141110545084, 'recall': 0.2046, 'f1': 0.2938388625592417, 'f2': 0.23289168146428085, 'roc': 0.5077896440780214}

# %%
results_DDOS_HOIC = aeknn.compute_results(np.concatenate((X_DDOS_HOIC_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_DDOS_HOIC_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_DDOS_HOIC)
# Out:
# {'acc': 0.655319362278151, 'precision': 0.7269426289034132, 'recall': 0.5005, 'f1': 0.5928338762214983, 'f2': 0.533752799402794, 'roc': 0.6557396440780213}

# %%
results_DDOS_GOLDEN_EYE = aeknn.compute_results(np.concatenate((X_DDOS_GOLDEN_EYE_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_DDOS_GOLDEN_EYE_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_DDOS_GOLDEN_EYE)
# Out:
# {'acc': 0.7191416825428657, 'precision': 0.7695513606276048, 'recall': 0.6278, 'f1': 0.6914858464588611, 'f2': 0.6518127829228788, 'roc': 0.7193896440780214}

# %%
results_OOD_INFIL = aeknn.compute_results(np.concatenate((X_OOD_INFIL_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_OOD_INFIL_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_OOD_INFIL)
# Out:
# {'acc': 0.43402185901935225, 'precision': 0.23917442331040065, 'recall': 0.0591, 'f1': 0.09477988934327639, 'f2': 0.06957688775870594, 'roc': 0.4350396440780213}
