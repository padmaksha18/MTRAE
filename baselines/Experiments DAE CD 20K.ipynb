# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/Shareddrives/Anomaly/
# Out:
# /content/gdrive/Shareddrives/Anomaly

# %%
import pandas as pd
import numpy as np
from sklearn.utils import resample

# %%
train_df = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/TRAIN_FINAL_CROSS_DOM_20K.csv')

# %%
train_df.head()
# Out:
#    Fwd Pkt Len Max  Fwd Pkt Len Min  Fwd Pkt Len Mean  Fwd Pkt Len Std  \
# 0        -0.632694        -0.580092         -0.881051        -0.598698
# 1        -0.712442         1.429695         -0.374214        -0.852608
# 2        -0.632694        -0.580092         -0.881051        -0.598698
# 3        -0.512219         0.741109         -0.261913        -0.598698
# 4         1.709488        -0.580092          1.686548         1.800385
#
#    Bwd Pkt Len Max  Bwd Pkt Len Min  Bwd Pkt Len Mean  Bwd Pkt Len Std  \
# 0        -0.686276        -0.635757         -0.698694        -0.588015
# 1        -0.536097         3.273131          0.201001        -0.794297
# 2        -0.686276        -0.635757         -0.698694        -0.588015
# 3        -0.468995         1.592125         -0.091600        -0.588015
# 4         1.352691        -0.635757         -0.000646         0.862475
#
#    Flow Byts/s  Flow Pkts/s  ...  Pkt Len Std  Pkt Len Var  Pkt Size Avg  \
# 0    -0.085003     0.369437  ...    -0.694505    -0.517268     -0.835366
# 1    -0.068330    -0.136598  ...    -0.490374    -0.598422      0.082195
# 2    -0.085003    -0.164555  ...    -0.694505    -0.517268     -0.835366
# 3    -0.081888    -0.163937  ...    -0.416409    -0.490281     -0.084858
# 4    -0.084752    -0.164529  ...     0.844407     0.309143      0.273510
#
#    Fwd Seg Size Avg  Bwd Seg Size Avg  Init Fwd Win Byts  Init Bwd Win Byts  \
# 0         -0.881051         -0.698694           0.130146          -0.314942
# 1         -0.374214          0.201001          -0.755270          -0.426041
# 2         -0.881051         -0.698694          -0.468538          -0.314942
# 3         -0.261913         -0.091600          -0.468538          -0.314942
# 4          1.686548         -0.000646           0.481678           4.010477
#
#    Fwd Seg Size Min  Idle Min  Label
# 0          0.680731 -0.344192    0.0
# 1         -1.445423 -0.361189    0.0
# 2         -2.426335  1.906829    0.0
# 3         -1.183509 -0.344192    0.0
# 4          0.680731 -0.344192    0.0
#
# [5 rows x 30 columns]

# %%
X_train = train_df.drop(labels = ['Label'], axis=1)

# %%
X_train.head()
# Out:
#    Fwd Pkt Len Max  Fwd Pkt Len Min  Fwd Pkt Len Mean  Fwd Pkt Len Std  \
# 0        -0.632694        -0.580092         -0.881051        -0.598698
# 1        -0.712442         1.429695         -0.374214        -0.852608
# 2        -0.632694        -0.580092         -0.881051        -0.598698
# 3        -0.512219         0.741109         -0.261913        -0.598698
# 4         1.709488        -0.580092          1.686548         1.800385
#
#    Bwd Pkt Len Max  Bwd Pkt Len Min  Bwd Pkt Len Mean  Bwd Pkt Len Std  \
# 0        -0.686276        -0.635757         -0.698694        -0.588015
# 1        -0.536097         3.273131          0.201001        -0.794297
# 2        -0.686276        -0.635757         -0.698694        -0.588015
# 3        -0.468995         1.592125         -0.091600        -0.588015
# 4         1.352691        -0.635757         -0.000646         0.862475
#
#    Flow Byts/s  Flow Pkts/s  ...  Pkt Len Mean  Pkt Len Std  Pkt Len Var  \
# 0    -0.085003     0.369437  ...     -0.745314    -0.694505    -0.517268
# 1    -0.068330    -0.136598  ...     -0.019745    -0.490374    -0.598422
# 2    -0.085003    -0.164555  ...     -0.745314    -0.694505    -0.517268
# 3    -0.081888    -0.163937  ...     -0.231251    -0.416409    -0.490281
# 4    -0.084752    -0.164529  ...      0.337016     0.844407     0.309143
#
#    Pkt Size Avg  Fwd Seg Size Avg  Bwd Seg Size Avg  Init Fwd Win Byts  \
# 0     -0.835366         -0.881051         -0.698694           0.130146
# 1      0.082195         -0.374214          0.201001          -0.755270
# 2     -0.835366         -0.881051         -0.698694          -0.468538
# 3     -0.084858         -0.261913         -0.091600          -0.468538
# 4      0.273510          1.686548         -0.000646           0.481678
#
#    Init Bwd Win Byts  Fwd Seg Size Min  Idle Min
# 0          -0.314942          0.680731 -0.344192
# 1          -0.426041         -1.445423 -0.361189
# 2          -0.314942         -2.426335  1.906829
# 3          -0.314942         -1.183509 -0.344192
# 4           4.010477          0.680731 -0.344192
#
# [5 rows x 29 columns]

# %%
X_train.shape
# Out:
# (156903, 29)

# %%
X_train = X_train.to_numpy()

# %%
y_train = train_df['Label']

# %%
y_train.value_counts()
# Out:
# 0.0    91315
# 1.0    65588
# Name: Label, dtype: int64

# %%
y_train[y_train>1.0]=1.0

# %%
y_train = y_train.to_numpy()

# %%
y_train.shape
# Out:
# (156903,)

# %%
y_train_0 = y_train[y_train == 0]

# %%
y_train_1 = y_train[y_train == 1]

# %%
print(y_train_0.shape, y_train_1.shape)
# Out:
# (91315,) (65588,)

# %%
X_train_0 = X_train[y_train == 0]

# %%
X_train_1 = X_train[y_train == 1]

# %%
print(X_train_0.shape, X_train_1.shape)
# Out:
# (91315, 29) (65588, 29)

# %%
X_train_0, y_train_0, X_train_1, y_train_1 = X_train_0[0:90000], y_train_0[0:90000], X_train_1[0:50000], y_train_1[0:50000]

# %%
y_train = np.concatenate((y_train_0, y_train_1))

# %%
print(X_train_0.shape, X_train_1.shape)
# Out:
# (90000, 29) (50000, 29)

# %%
X_train = np.concatenate((X_train_0, X_train_1))

# %%
print(X_train.shape, y_train.shape)
# Out:
# (140000, 29) (140000,)

# %%
Xo_train = np.concatenate((X_train_0, X_train_0[0:50000]))

# %%
print(Xo_train.shape)
# Out:
# (140000, 29)

# %%
BOT_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/BOT.csv')

# %%
BOT_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_BOT_test = BOT_test.drop(labels = ['Label'], axis=1)

# %%
X_BOT_test = X_BOT_test.to_numpy()

# %%
y_BOT_test = BOT_test['Label']

# %%
y_BOT_test.value_counts()
# Out:
# 1.0    10000
# Name: Label, dtype: int64

# %%
y_BOT_test[y_BOT_test>1.0] = 1.0

# %%
y_BOT_test = y_BOT_test.to_numpy()

# %%
RARE_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/RARE.csv')

# %%
RARE_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_RARE_test = RARE_test.drop(labels = ['Label'], axis=1)

# %%
X_RARE_test = X_RARE_test.to_numpy()

# %%
y_RARE_test = RARE_test['Label']

# %%
y_RARE_test.value_counts()
# Out:
# 1.0    566
# Name: Label, dtype: int64

# %%
y_RARE_test[y_RARE_test>1.0] = 1.0

# %%
y_RARE_test = y_RARE_test.to_numpy()

# %%
SlowHTTPTest_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/SlowHTTPTest.csv')

# %%
SlowHTTPTest_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_SlowHTTPTest_test = SlowHTTPTest_test.drop(labels = ['Label'], axis=1)

# %%
X_SlowHTTPTest_test = X_SlowHTTPTest_test.to_numpy()

# %%
y_SlowHTTPTest_test = SlowHTTPTest_test['Label']

# %%
y_SlowHTTPTest_test.value_counts()
# Out:
# 1.0    461912
# Name: Label, dtype: int64

# %%
y_SlowHTTPTest_test[y_SlowHTTPTest_test>1.0] = 1.0

# %%
y_SlowHTTPTest_test = y_SlowHTTPTest_test.to_numpy()

# %%
DDOS_SOLARIS_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/DDOS_SOLARIS.csv')

# %%
DDOS_SOLARIS_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_DDOS_SOLARIS_test = DDOS_SOLARIS_test.drop(labels = ['Label'], axis=1)

# %%
X_DDOS_SOLARIS_test = X_DDOS_SOLARIS_test.to_numpy()

# %%
y_DDOS_SOLARIS_test = DDOS_SOLARIS_test['Label']

# %%
y_DDOS_SOLARIS_test.value_counts()
# Out:
# 1.0    10990
# Name: Label, dtype: int64

# %%
y_DDOS_SOLARIS_test[y_DDOS_SOLARIS_test>1.0] = 1.0

# %%
y_DDOS_SOLARIS_test = y_DDOS_SOLARIS_test.to_numpy()

# %%
DDOS_HOIC_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/DDOS_HOIC.csv')

# %%
DDOS_HOIC_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_DDOS_HOIC_test = DDOS_HOIC_test.drop(labels = ['Label'], axis=1)

# %%
X_DDOS_HOIC_test = X_DDOS_HOIC_test.to_numpy()

# %%
y_DDOS_HOIC_test = DDOS_HOIC_test['Label']

# %%
y_DDOS_HOIC_test.value_counts()
# Out:
# 1.0    686012
# Name: Label, dtype: int64

# %%
y_DDOS_HOIC_test[y_DDOS_HOIC_test>1.0] = 1.0

# %%
y_DDOS_HOIC_test = y_DDOS_HOIC_test.to_numpy()

# %%
DDOS_GOLDEN_EYE_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/DDOS_GOLDEN_EYE.csv')

# %%
DDOS_GOLDEN_EYE_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_DDOS_GOLDEN_EYE_test = DDOS_GOLDEN_EYE_test.drop(labels = ['Label'], axis=1)

# %%
X_DDOS_GOLDEN_EYE_test = X_DDOS_GOLDEN_EYE_test.to_numpy()

# %%
y_DDOS_GOLDEN_EYE_test = DDOS_GOLDEN_EYE_test['Label']

# %%
y_DDOS_GOLDEN_EYE_test.value_counts()
# Out:
# 1.0    41508
# Name: Label, dtype: int64

# %%
y_DDOS_GOLDEN_EYE_test[y_DDOS_GOLDEN_EYE_test>1.0] = 1.0

# %%
y_DDOS_GOLDEN_EYE_test = y_DDOS_GOLDEN_EYE_test.to_numpy()

# %%
OOD_INFIL_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/OOD_INFIL.csv')

# %%
OOD_INFIL_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_OOD_INFIL_test = OOD_INFIL_test.drop(labels = ['Label'], axis=1)

# %%
X_OOD_INFIL_test = X_OOD_INFIL_test.to_numpy()

# %%
y_OOD_INFIL_test = OOD_INFIL_test['Label']

# %%
y_OOD_INFIL_test.value_counts()
# Out:
# 1.0    49504
# Name: Label, dtype: int64

# %%
y_OOD_INFIL_test[y_OOD_INFIL_test>1.0] = 1.0

# %%
y_OOD_INFIL_test = y_OOD_INFIL_test.to_numpy()

# %%
BENIGN_TEST_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/BENIGN_TEST.csv')

# %%
BENIGN_TEST_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_BENIGN_TEST_test = BENIGN_TEST_test.drop(labels = ['Label'], axis=1)

# %%
X_BENIGN_TEST_test = X_BENIGN_TEST_test.to_numpy()

# %%
y_BENIGN_TEST_test = BENIGN_TEST_test['Label']

# %%
y_BENIGN_TEST_test.value_counts()
# Out:
# 0.0    9946
# Name: Label, dtype: int64

# %%
y_BENIGN_TEST_test[y_BENIGN_TEST_test>1.0] = 1.0

# %%
y_BENIGN_TEST_test = y_BENIGN_TEST_test.to_numpy()

# %%
from models.dae_svm import DAESVMModel
# from models.bigan import BiGANModel
# from models.seq2seq import Seq2SeqModel
from utils import eval_utils

# %%
ae_kwargs = {}
ae_kwargs["latent_dim"] = 7
ae_kwargs["hidden_layers"] = 2
ae_kwargs["hidden_dim"] = [20, 14]
ae_kwargs["epochs"] = 50
ae_kwargs["batch_size"] = 32
ae_kwargs["learning_rate"] = 0.001
ae_kwargs["output_activation"] = "relu"
# ae_kwargs["model_path"] = ae_model_path

# %%
aeknn = DAESVMModel(X_train.shape[1], **ae_kwargs)
aeknn.train(X_train, X_BENIGN_TEST_test, y_train, Xo_train)
#aeknn.save_model()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 29)]              0
#
#  encoder_hidden_0 (Dense)    (None, 20)                600
#
#  batch_normalization (Batch  (None, 20)                80
#  Normalization)
#
#  encoder_hidden_1 (Dense)    (None, 14)                294
#
#  batch_normalization_1 (Bat  (None, 14)                56
#  chNormalization)
#
#  z_ (Dense)                  (None, 7)                 105
#
# =================================================================
# Total params: 1135 (4.43 KB)
# Trainable params: 1067 (4.17 KB)
# Non-trainable params: 68 (272.00 Byte)
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_ (InputLayer)             [(None, 7)]               0
#
#  decoder_hidden_0 (Dense)    (None, 14)                112
#
#  batch_normalization_2 (Bat  (None, 14)                56
#  chNormalization)
#
#  decoder_hidden_1 (Dense)    (None, 20)                300
#
#  batch_normalization_3 (Bat  (None, 20)                80
#  chNormalization)
#
#  decoder_output (Dense)      (None, 29)                609
#
# =================================================================
# Total params: 1157 (4.52 KB)
# Trainable params: 1089 (4.25 KB)
# Non-trainable params: 68 (272.00 Byte)
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 4375/4375 [==============================] - 30s 5ms/step - loss: 0.6473 - val_loss: 0.8043
# Epoch 2/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5695 - val_loss: 0.4748
# Epoch 3/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5556 - val_loss: 0.5897
# Epoch 4/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5489 - val_loss: 0.5276
# Epoch 5/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5442 - val_loss: 0.3787
# Epoch 6/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5426 - val_loss: 0.4025
# Epoch 7/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5396 - val_loss: 0.4215
# Epoch 8/50
# 4375/4375 [==============================] - 21s 5ms/step - loss: 0.5385 - val_loss: 0.3519
# Epoch 9/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5383 - val_loss: 0.3889
# Epoch 10/50
# 4375/4375 [==============================] - 21s 5ms/step - loss: 0.5373 - val_loss: 0.3546
# Epoch 11/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5355 - val_loss: 0.3546
# Epoch 12/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5355 - val_loss: 0.3844
# Epoch 13/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5344 - val_loss: 0.3436
# Epoch 14/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5343 - val_loss: 0.3828
# Epoch 15/50
# 4375/4375 [==============================] - 21s 5ms/step - loss: 0.5328 - val_loss: 0.4225
# Epoch 16/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5327 - val_loss: 0.4189
# Epoch 17/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5326 - val_loss: 0.3858
# Epoch 18/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5321 - val_loss: 0.4176
# Epoch 19/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5316 - val_loss: 0.4131
# Epoch 20/50
# 4375/4375 [==============================] - 21s 5ms/step - loss: 0.5305 - val_loss: 0.4305
# Epoch 21/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5309 - val_loss: 0.4544
# Epoch 22/50
# 4375/4375 [==============================] - 21s 5ms/step - loss: 0.5293 - val_loss: 0.5048
# Epoch 23/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5300 - val_loss: 0.4609
# Epoch 24/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5289 - val_loss: 0.4743
# Epoch 25/50
# 4375/4375 [==============================] - 21s 5ms/step - loss: 0.5283 - val_loss: 0.4904
# Epoch 26/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5283 - val_loss: 0.4258
# Epoch 27/50
# 4375/4375 [==============================] - 21s 5ms/step - loss: 0.5284 - val_loss: 0.4919
# Epoch 28/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5266 - val_loss: 0.5182
# Epoch 29/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5280 - val_loss: 0.4565
# Epoch 30/50
# 4375/4375 [==============================] - 21s 5ms/step - loss: 0.5273 - val_loss: 0.5566
# Epoch 31/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5269 - val_loss: 0.6065
# Epoch 32/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5266 - val_loss: 0.5506
# Epoch 33/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5256 - val_loss: 0.5881
# Epoch 34/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5256 - val_loss: 0.5055
# Epoch 35/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5258 - val_loss: 0.4954
# Epoch 36/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5258 - val_loss: 0.8218
# Epoch 37/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5251 - val_loss: 1.0009
# Epoch 38/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5254 - val_loss: 0.4840
# Epoch 39/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5244 - val_loss: 0.6279
# Epoch 40/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5241 - val_loss: 0.4709
# Epoch 41/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5249 - val_loss: 1.1255
# Epoch 42/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5232 - val_loss: 0.4815
# Epoch 43/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5235 - val_loss: 0.5251
# Epoch 44/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5237 - val_loss: 0.5285
# Epoch 45/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5234 - val_loss: 0.4875
# Epoch 46/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5226 - val_loss: 0.6175
# Epoch 47/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5229 - val_loss: 0.6114
# Epoch 48/50
# 4375/4375 [==============================] - 21s 5ms/step - loss: 0.5226 - val_loss: 0.6464
# Epoch 49/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5224 - val_loss: 0.7142
# Epoch 50/50
# 4375/4375 [==============================] - 22s 5ms/step - loss: 0.5225 - val_loss: 0.7949

# %%
results_BOT = aeknn.compute_results(np.concatenate((X_BOT_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_BOT_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_BOT)
# Out:
# {'acc': 0.8620274741802868, 'precision': 0.7871177309459674, 'recall': 0.9935, 'f1': 0.8783485102997083, 'f2': 0.9439968074189503, 'roc': 0.8616705710838528}

# %%
results_RARE = aeknn.compute_results(np.concatenate((X_RARE_test[:566], X_BENIGN_TEST_test[:566])), np.concatenate((y_RARE_test[:566], y_BENIGN_TEST_test[:566])))
print(results_RARE)
# Out:
# {'acc': 0.75, 'precision': 0.7338842975206612, 'recall': 0.784452296819788, 'f1': 0.7583262169086251, 'f2': 0.7737887765772047, 'roc': 0.75}

# %%
results_SlowHTTPTest = aeknn.compute_results(np.concatenate((X_SlowHTTPTest_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_SlowHTTPTest_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_SlowHTTPTest)
# Out:
# {'acc': 0.6130552491727664, 'precision': 0.6490334378265413, 'recall': 0.4969, 'f1': 0.5628681468056185, 'f2': 0.5213404398187007, 'roc': 0.6133705710838527}

# %%
results_DDOS_SOLARIS = aeknn.compute_results(np.concatenate((X_DDOS_SOLARIS_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_DDOS_SOLARIS_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_DDOS_SOLARIS)
# Out:
# {'acc': 0.6449914769878673, 'precision': 0.6759918003135175, 'recall': 0.5606, 'f1': 0.6129120428579238, 'f2': 0.5804153811111341, 'roc': 0.6452205710838528}

# %%
results_DDOS_HOIC = aeknn.compute_results(np.concatenate((X_DDOS_HOIC_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_DDOS_HOIC_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_DDOS_HOIC)
# Out:
# {'acc': 0.8415221096961797, 'precision': 0.7799885368050438, 'recall': 0.9526, 'f1': 0.8576959438166839, 'f2': 0.9122249248271503, 'roc': 0.8412205710838527}

# %%
results_DDOS_GOLDEN_EYE = aeknn.compute_results(np.concatenate((X_DDOS_GOLDEN_EYE_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_DDOS_GOLDEN_EYE_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_DDOS_GOLDEN_EYE)
# Out:
# {'acc': 0.5577058056753234, 'precision': 0.5898962148962149, 'recall': 0.3865, 'f1': 0.4670130497825037, 'f2': 0.4151271696167727, 'roc': 0.5581705710838528}

# %%
results_OOD_INFIL = aeknn.compute_results(np.concatenate((X_OOD_INFIL_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_OOD_INFIL_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_OOD_INFIL)
# Out:
# {'acc': 0.3930612654166249, 'precision': 0.17778457772337822, 'recall': 0.0581, 'f1': 0.08757913777509799, 'f2': 0.0671396875288897, 'roc': 0.3939705710838528}
