# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/Shareddrives/Anomaly/
# Out:
# /content/gdrive/Shareddrives/Anomaly

# %%
import pandas as pd
import numpy as np
from sklearn.utils import resample

# %%
train_df = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/TRAIN_FINAL_CROSS_DOM_3K.csv')

# %%
train_df.head()
# Out:
#    Fwd Pkt Len Max  Fwd Pkt Len Min  Fwd Pkt Len Mean  Fwd Pkt Len Std  \
# 0        -0.632694        -0.580092         -0.881051        -0.598698
# 1        -0.712442         1.429695         -0.374214        -0.852608
# 2        -0.632694        -0.580092         -0.881051        -0.598698
# 3        -0.512219         0.741109         -0.261913        -0.598698
# 4         1.709488        -0.580092          1.686548         1.800385
#
#    Bwd Pkt Len Max  Bwd Pkt Len Min  Bwd Pkt Len Mean  Bwd Pkt Len Std  \
# 0        -0.686276        -0.635757         -0.698694        -0.588015
# 1        -0.536097         3.273131          0.201001        -0.794297
# 2        -0.686276        -0.635757         -0.698694        -0.588015
# 3        -0.468995         1.592125         -0.091600        -0.588015
# 4         1.352691        -0.635757         -0.000646         0.862475
#
#    Flow Byts/s  Flow Pkts/s  ...  Pkt Len Std  Pkt Len Var  Pkt Size Avg  \
# 0    -0.085003     0.369437  ...    -0.694505    -0.517268     -0.835366
# 1    -0.068330    -0.136598  ...    -0.490374    -0.598422      0.082195
# 2    -0.085003    -0.164555  ...    -0.694505    -0.517268     -0.835366
# 3    -0.081888    -0.163937  ...    -0.416409    -0.490281     -0.084858
# 4    -0.084752    -0.164529  ...     0.844407     0.309143      0.273510
#
#    Fwd Seg Size Avg  Bwd Seg Size Avg  Init Fwd Win Byts  Init Bwd Win Byts  \
# 0         -0.881051         -0.698694           0.130146          -0.314942
# 1         -0.374214          0.201001          -0.755270          -0.426041
# 2         -0.881051         -0.698694          -0.468538          -0.314942
# 3         -0.261913         -0.091600          -0.468538          -0.314942
# 4          1.686548         -0.000646           0.481678           4.010477
#
#    Fwd Seg Size Min  Idle Min  Label
# 0          0.680731 -0.344192    0.0
# 1         -1.445423 -0.361189    0.0
# 2         -2.426335  1.906829    0.0
# 3         -1.183509 -0.344192    0.0
# 4          0.680731 -0.344192    0.0
#
# [5 rows x 30 columns]

# %%
X_train = train_df.drop(labels = ['Label'], axis=1)

# %%
X_train.head()
# Out:
#    Fwd Pkt Len Max  Fwd Pkt Len Min  Fwd Pkt Len Mean  Fwd Pkt Len Std  \
# 0        -0.632694        -0.580092         -0.881051        -0.598698
# 1        -0.712442         1.429695         -0.374214        -0.852608
# 2        -0.632694        -0.580092         -0.881051        -0.598698
# 3        -0.512219         0.741109         -0.261913        -0.598698
# 4         1.709488        -0.580092          1.686548         1.800385
#
#    Bwd Pkt Len Max  Bwd Pkt Len Min  Bwd Pkt Len Mean  Bwd Pkt Len Std  \
# 0        -0.686276        -0.635757         -0.698694        -0.588015
# 1        -0.536097         3.273131          0.201001        -0.794297
# 2        -0.686276        -0.635757         -0.698694        -0.588015
# 3        -0.468995         1.592125         -0.091600        -0.588015
# 4         1.352691        -0.635757         -0.000646         0.862475
#
#    Flow Byts/s  Flow Pkts/s  ...  Pkt Len Mean  Pkt Len Std  Pkt Len Var  \
# 0    -0.085003     0.369437  ...     -0.745314    -0.694505    -0.517268
# 1    -0.068330    -0.136598  ...     -0.019745    -0.490374    -0.598422
# 2    -0.085003    -0.164555  ...     -0.745314    -0.694505    -0.517268
# 3    -0.081888    -0.163937  ...     -0.231251    -0.416409    -0.490281
# 4    -0.084752    -0.164529  ...      0.337016     0.844407     0.309143
#
#    Pkt Size Avg  Fwd Seg Size Avg  Bwd Seg Size Avg  Init Fwd Win Byts  \
# 0     -0.835366         -0.881051         -0.698694           0.130146
# 1      0.082195         -0.374214          0.201001          -0.755270
# 2     -0.835366         -0.881051         -0.698694          -0.468538
# 3     -0.084858         -0.261913         -0.091600          -0.468538
# 4      0.273510          1.686548         -0.000646           0.481678
#
#    Init Bwd Win Byts  Fwd Seg Size Min  Idle Min
# 0          -0.314942          0.680731 -0.344192
# 1          -0.426041         -1.445423 -0.361189
# 2          -0.314942         -2.426335  1.906829
# 3          -0.314942         -1.183509 -0.344192
# 4           4.010477          0.680731 -0.344192
#
# [5 rows x 29 columns]

# %%
X_train.shape
# Out:
# (156903, 29)

# %%
X_train = X_train.to_numpy()

# %%
y_train = train_df['Label']

# %%
y_train.value_counts()
# Out:
# 0.0    102393
# 1.0     54510
# Name: Label, dtype: int64

# %%
y_train[y_train>1.0]=1.0

# %%
y_train = y_train.to_numpy()

# %%
y_train.shape
# Out:
# (156903,)

# %%
y_train_0 = y_train[y_train == 0]

# %%
y_train_1 = y_train[y_train == 1]

# %%
print(y_train_0.shape, y_train_1.shape)
# Out:
# (102393,) (54510,)

# %%
X_train_0 = X_train[y_train == 0]

# %%
X_train_1 = X_train[y_train == 1]

# %%
print(X_train_0.shape, X_train_1.shape)
# Out:
# (102393, 29) (54510, 29)

# %%
X_train_0, y_train_0, X_train_1, y_train_1 = X_train_0[0:90000], y_train_0[0:90000], X_train_1[0:50000], y_train_1[0:50000]

# %%
y_train = np.concatenate((y_train_0, y_train_1))

# %%
print(X_train_0.shape, X_train_1.shape)
# Out:
# (90000, 29) (50000, 29)

# %%
X_train = np.concatenate((X_train_0, X_train_1))

# %%
print(X_train.shape, y_train.shape)
# Out:
# (140000, 29) (140000,)

# %%
Xo_train = np.concatenate((X_train_0, X_train_0[0:50000]))

# %%
print(Xo_train.shape)
# Out:
# (140000, 29)

# %%
BOT_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/BOT.csv')

# %%
BOT_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_BOT_test = BOT_test.drop(labels = ['Label'], axis=1)

# %%
X_BOT_test = X_BOT_test.to_numpy()

# %%
y_BOT_test = BOT_test['Label']

# %%
y_BOT_test.value_counts()
# Out:
# 1.0    10000
# Name: Label, dtype: int64

# %%
y_BOT_test[y_BOT_test>1.0] = 1.0

# %%
y_BOT_test = y_BOT_test.to_numpy()

# %%
RARE_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/RARE.csv')

# %%
RARE_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_RARE_test = RARE_test.drop(labels = ['Label'], axis=1)

# %%
X_RARE_test = X_RARE_test.to_numpy()

# %%
y_RARE_test = RARE_test['Label']

# %%
y_RARE_test.value_counts()
# Out:
# 1.0    566
# Name: Label, dtype: int64

# %%
y_RARE_test[y_RARE_test>1.0] = 1.0

# %%
y_RARE_test = y_RARE_test.to_numpy()

# %%
SlowHTTPTest_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/SlowHTTPTest.csv')

# %%
SlowHTTPTest_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_SlowHTTPTest_test = SlowHTTPTest_test.drop(labels = ['Label'], axis=1)

# %%
X_SlowHTTPTest_test = X_SlowHTTPTest_test.to_numpy()

# %%
y_SlowHTTPTest_test = SlowHTTPTest_test['Label']

# %%
y_SlowHTTPTest_test.value_counts()
# Out:
# 1.0    461912
# Name: Label, dtype: int64

# %%
y_SlowHTTPTest_test[y_SlowHTTPTest_test>1.0] = 1.0

# %%
y_SlowHTTPTest_test = y_SlowHTTPTest_test.to_numpy()

# %%
DDOS_SOLARIS_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/DDOS_SOLARIS.csv')

# %%
DDOS_SOLARIS_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_DDOS_SOLARIS_test = DDOS_SOLARIS_test.drop(labels = ['Label'], axis=1)

# %%
X_DDOS_SOLARIS_test = X_DDOS_SOLARIS_test.to_numpy()

# %%
y_DDOS_SOLARIS_test = DDOS_SOLARIS_test['Label']

# %%
y_DDOS_SOLARIS_test.value_counts()
# Out:
# 1.0    10990
# Name: Label, dtype: int64

# %%
y_DDOS_SOLARIS_test[y_DDOS_SOLARIS_test>1.0] = 1.0

# %%
y_DDOS_SOLARIS_test = y_DDOS_SOLARIS_test.to_numpy()

# %%
DDOS_HOIC_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/DDOS_HOIC.csv')

# %%
DDOS_HOIC_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_DDOS_HOIC_test = DDOS_HOIC_test.drop(labels = ['Label'], axis=1)

# %%
X_DDOS_HOIC_test = X_DDOS_HOIC_test.to_numpy()

# %%
y_DDOS_HOIC_test = DDOS_HOIC_test['Label']

# %%
y_DDOS_HOIC_test.value_counts()
# Out:
# 1.0    686012
# Name: Label, dtype: int64

# %%
y_DDOS_HOIC_test[y_DDOS_HOIC_test>1.0] = 1.0

# %%
y_DDOS_HOIC_test = y_DDOS_HOIC_test.to_numpy()

# %%
DDOS_GOLDEN_EYE_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/DDOS_GOLDEN_EYE.csv')

# %%
DDOS_GOLDEN_EYE_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_DDOS_GOLDEN_EYE_test = DDOS_GOLDEN_EYE_test.drop(labels = ['Label'], axis=1)

# %%
X_DDOS_GOLDEN_EYE_test = X_DDOS_GOLDEN_EYE_test.to_numpy()

# %%
y_DDOS_GOLDEN_EYE_test = DDOS_GOLDEN_EYE_test['Label']

# %%
y_DDOS_GOLDEN_EYE_test.value_counts()
# Out:
# 1.0    41508
# Name: Label, dtype: int64

# %%
y_DDOS_GOLDEN_EYE_test[y_DDOS_GOLDEN_EYE_test>1.0] = 1.0

# %%
y_DDOS_GOLDEN_EYE_test = y_DDOS_GOLDEN_EYE_test.to_numpy()

# %%
OOD_INFIL_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/OOD_INFIL.csv')

# %%
OOD_INFIL_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_OOD_INFIL_test = OOD_INFIL_test.drop(labels = ['Label'], axis=1)

# %%
X_OOD_INFIL_test = X_OOD_INFIL_test.to_numpy()

# %%
y_OOD_INFIL_test = OOD_INFIL_test['Label']

# %%
y_OOD_INFIL_test.value_counts()
# Out:
# 1.0    49504
# Name: Label, dtype: int64

# %%
y_OOD_INFIL_test[y_OOD_INFIL_test>1.0] = 1.0

# %%
y_OOD_INFIL_test = y_OOD_INFIL_test.to_numpy()

# %%
BENIGN_TEST_test = pd.read_csv('/content/gdrive/Shareddrives/Anomaly/dataset/BENIGN_TEST.csv')

# %%
BENIGN_TEST_test.isna().sum()
# Out:
# Fwd Pkt Len Max      0
# Fwd Pkt Len Min      0
# Fwd Pkt Len Mean     0
# Fwd Pkt Len Std      0
# Bwd Pkt Len Max      0
# Bwd Pkt Len Min      0
# Bwd Pkt Len Mean     0
# Bwd Pkt Len Std      0
# Flow Byts/s          0
# Flow Pkts/s          0
# Bwd IAT Tot          0
# Bwd IAT Mean         0
# Bwd IAT Std          0
# Bwd IAT Max          0
# Bwd IAT Min          0
# Fwd Pkts/s           0
# Bwd Pkts/s           0
# Pkt Len Min          0
# Pkt Len Max          0
# Pkt Len Mean         0
# Pkt Len Std          0
# Pkt Len Var          0
# Pkt Size Avg         0
# Fwd Seg Size Avg     0
# Bwd Seg Size Avg     0
# Init Fwd Win Byts    0
# Init Bwd Win Byts    0
# Fwd Seg Size Min     0
# Idle Min             0
# Label                0
# dtype: int64

# %%
X_BENIGN_TEST_test = BENIGN_TEST_test.drop(labels = ['Label'], axis=1)

# %%
X_BENIGN_TEST_test = X_BENIGN_TEST_test.to_numpy()

# %%
y_BENIGN_TEST_test = BENIGN_TEST_test['Label']

# %%
y_BENIGN_TEST_test.value_counts()
# Out:
# 0.0    9946
# Name: Label, dtype: int64

# %%
y_BENIGN_TEST_test[y_BENIGN_TEST_test>1.0] = 1.0

# %%
y_BENIGN_TEST_test = y_BENIGN_TEST_test.to_numpy()

# %%
from models.dae_svm import DAESVMModel
# from models.bigan import BiGANModel
# from models.seq2seq import Seq2SeqModel
from utils import eval_utils

# %%
ae_kwargs = {}
ae_kwargs["latent_dim"] = 7
ae_kwargs["hidden_layers"] = 2
ae_kwargs["hidden_dim"] = [20, 14]
ae_kwargs["epochs"] = 50
ae_kwargs["batch_size"] = 32
ae_kwargs["learning_rate"] = 0.001
ae_kwargs["output_activation"] = "relu"
# ae_kwargs["model_path"] = ae_model_path

# %%
aeknn = DAESVMModel(X_train.shape[1], **ae_kwargs)
aeknn.train(X_train, X_BENIGN_TEST_test, y_train, Xo_train)
#aeknn.save_model()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 29)]              0
#
#  encoder_hidden_0 (Dense)    (None, 20)                600
#
#  batch_normalization (Batch  (None, 20)                80
#  Normalization)
#
#  encoder_hidden_1 (Dense)    (None, 14)                294
#
#  batch_normalization_1 (Bat  (None, 14)                56
#  chNormalization)
#
#  z_ (Dense)                  (None, 7)                 105
#
# =================================================================
# Total params: 1135 (4.43 KB)
# Trainable params: 1067 (4.17 KB)
# Non-trainable params: 68 (272.00 Byte)
# _________________________________________________________________
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_ (InputLayer)             [(None, 7)]               0
#
#  decoder_hidden_0 (Dense)    (None, 14)                112
#
#  batch_normalization_2 (Bat  (None, 14)                56
#  chNormalization)
#
#  decoder_hidden_1 (Dense)    (None, 20)                300
#
#  batch_normalization_3 (Bat  (None, 20)                80
#  chNormalization)
#
#  decoder_output (Dense)      (None, 29)                609
#
# =================================================================
# Total params: 1157 (4.52 KB)
# Trainable params: 1089 (4.25 KB)
# Non-trainable params: 68 (272.00 Byte)
# _________________________________________________________________
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1/50
# 4375/4375 [==============================] - 33s 6ms/step - loss: 0.6543 - val_loss: 0.4880
# Epoch 2/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5594 - val_loss: 0.5245
# Epoch 3/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5425 - val_loss: 0.5425
# Epoch 4/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5345 - val_loss: 0.4267
# Epoch 5/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5322 - val_loss: 0.4046
# Epoch 6/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5287 - val_loss: 0.3740
# Epoch 7/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5270 - val_loss: 0.3767
# Epoch 8/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5248 - val_loss: 0.3931
# Epoch 9/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5239 - val_loss: 0.3298
# Epoch 10/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5227 - val_loss: 0.4216
# Epoch 11/50
# 4375/4375 [==============================] - 25s 6ms/step - loss: 0.5216 - val_loss: 0.3249
# Epoch 12/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5212 - val_loss: 0.3653
# Epoch 13/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5200 - val_loss: 0.3489
# Epoch 14/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5194 - val_loss: 0.3425
# Epoch 15/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5195 - val_loss: 0.3790
# Epoch 16/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5190 - val_loss: 0.3334
# Epoch 17/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5189 - val_loss: 0.3750
# Epoch 18/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5182 - val_loss: 0.3373
# Epoch 19/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5180 - val_loss: 0.3540
# Epoch 20/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5178 - val_loss: 0.3334
# Epoch 21/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5165 - val_loss: 0.3540
# Epoch 22/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5171 - val_loss: 0.3516
# Epoch 23/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5167 - val_loss: 0.3113
# Epoch 24/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5165 - val_loss: 0.3260
# Epoch 25/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5173 - val_loss: 0.3114
# Epoch 26/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5156 - val_loss: 0.3642
# Epoch 27/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5164 - val_loss: 0.3612
# Epoch 28/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5153 - val_loss: 0.3676
# Epoch 29/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5152 - val_loss: 0.3677
# Epoch 30/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5150 - val_loss: 0.3296
# Epoch 31/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5148 - val_loss: 0.3519
# Epoch 32/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5145 - val_loss: 0.3454
# Epoch 33/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5147 - val_loss: 0.3444
# Epoch 34/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5147 - val_loss: 0.3583
# Epoch 35/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5144 - val_loss: 0.3372
# Epoch 36/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5144 - val_loss: 0.3148
# Epoch 37/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5143 - val_loss: 0.3291
# Epoch 38/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5140 - val_loss: 0.3370
# Epoch 39/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5140 - val_loss: 0.3518
# Epoch 40/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5136 - val_loss: 0.3485
# Epoch 41/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5144 - val_loss: 0.3894
# Epoch 42/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5138 - val_loss: 0.3482
# Epoch 43/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5133 - val_loss: 0.3302
# Epoch 44/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5131 - val_loss: 0.3242
# Epoch 45/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5131 - val_loss: 0.3708
# Epoch 46/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5130 - val_loss: 0.3515
# Epoch 47/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5131 - val_loss: 0.3442
# Epoch 48/50
# 4375/4375 [==============================] - 23s 5ms/step - loss: 0.5127 - val_loss: 0.4067
# Epoch 49/50
# 4375/4375 [==============================] - 24s 6ms/step - loss: 0.5130 - val_loss: 0.3301
# Epoch 50/50
# 4375/4375 [==============================] - 24s 5ms/step - loss: 0.5126 - val_loss: 0.3479

# %%
results_BOT = aeknn.compute_results(np.concatenate((X_BOT_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_BOT_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_BOT)
# Out:
# {'acc': 0.65722450616665, 'precision': 0.7317895353949876, 'recall': 0.4993, 'f1': 0.5935921060452951, 'f2': 0.5331781389488073, 'roc': 0.6576532173738187}

# %%
results_RARE = aeknn.compute_results(np.concatenate((X_RARE_test[:566], X_BENIGN_TEST_test[:566])), np.concatenate((y_RARE_test[:566], y_BENIGN_TEST_test[:566])))
print(results_RARE)
# Out:
# {'acc': 0.523851590106007, 'precision': 0.5555555555555556, 'recall': 0.23851590106007067, 'f1': 0.3337453646477132, 'f2': 0.26924611088950934, 'roc': 0.523851590106007}

# %%
results_SlowHTTPTest = aeknn.compute_results(np.concatenate((X_SlowHTTPTest_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_SlowHTTPTest_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_SlowHTTPTest)
# Out:
# {'acc': 0.5886894615461746, 'precision': 0.6645894428152492, 'recall': 0.3626, 'f1': 0.4692028985507246, 'f2': 0.39884723688841955, 'roc': 0.5893032173738186}

# %%
results_DDOS_SOLARIS = aeknn.compute_results(np.concatenate((X_DDOS_SOLARIS_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_DDOS_SOLARIS_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_DDOS_SOLARIS)
# Out:
# {'acc': 0.47588488920084226, 'precision': 0.42919525888958204, 'recall': 0.1376, 'f1': 0.2083901257004392, 'f2': 0.15923714298939962, 'roc': 0.4768032173738186}

# %%
results_DDOS_HOIC = aeknn.compute_results(np.concatenate((X_DDOS_HOIC_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_DDOS_HOIC_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_DDOS_HOIC)
# Out:
# {'acc': 0.6551689561816906, 'precision': 0.7301680920082572, 'recall': 0.4952, 'f1': 0.5901561196520081, 'f2': 0.5292633919028685, 'roc': 0.6556032173738187}

# %%
results_DDOS_GOLDEN_EYE = aeknn.compute_results(np.concatenate((X_DDOS_GOLDEN_EYE_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_DDOS_GOLDEN_EYE_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_DDOS_GOLDEN_EYE)
# Out:
# {'acc': 0.6557204452020455, 'precision': 0.7306050345944355, 'recall': 0.4963, 'f1': 0.591079616506878, 'f2': 0.5303143632594619, 'roc': 0.6561532173738186}

# %%
results_OOD_INFIL = aeknn.compute_results(np.concatenate((X_OOD_INFIL_test[:10000], X_BENIGN_TEST_test[:10000])), np.concatenate((y_OOD_INFIL_test[:10000], y_BENIGN_TEST_test[:10000])))
print(results_OOD_INFIL)
# Out:
# {'acc': 0.4503158528025669, 'precision': 0.3212166172106825, 'recall': 0.0866, 'f1': 0.1364209199747952, 'f2': 0.10141465242645681, 'roc': 0.4513032173738186}
