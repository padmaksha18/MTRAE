# %%
from google.colab import drive
#drive.flush_and_unmount()
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch import nn, optim
from torch.autograd import Variable
import pandas as pd
import numpy as np

# %%
# %cd /content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model
# Out:
# /content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model

# %%
# # Importing libraries
# import matplotlib.pyplot as plt
# import numpy as np
# import math

# # Using Numpy to create an array X
# X = np.arange(5, 30, 5)

# # Assign variables to the y axis part of the curve
# acc = [58.8,58.58, 73.14, 66.67, 23.75 ]
# prec = [41,40.16, 73.5, 44.23, 26.7]
# rec = [58.8, 58.58 ]
# auc = [87.4,97.75,99.84,99.84,100]

# # Plotting both the curves simultaneously
# plt.plot(X, acc, color='r', label='accuracy')
# plt.plot(X, prec, color='g', label='precision')
# plt.plot(X, rec, color='b', label='recall')
# #plt.plot(X, auc, color='o', label='auc')

# # Naming the x-axis, y-axis and the whole graph
# plt.xlabel("Nos of domains")
# plt.ylabel("Percentage")
# plt.title("Accuracy, precision, recall vs Number of Domains")

# # Adding legend, which helps us recognize the curve according to it's color
# plt.legend()

# # To load the display window
# plt.show()

# %%
#df.to_csv('/content/gdrive/MyDrive/OOD_generalization/Y.csv', index = False)

# %%
#np.save("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/data_final_train_10_dom_5k_infil_ftp_ssh.npy",data_final_train)

#np.save("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/data_final_train_10_dom_5k_ddos_hoic.npy",data_final_train)

#np.save("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/data_final_train_10_dom_5k_SOLARIS.npy",data_final_train)


#np.save("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/data_final_train_20dom_1k_DDOS_HOIC.npy",data_final_train)

#np.save("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/data_final_train_10_dom_INFIL_DDOS.npy",data_final_train)


#np.save("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/data_final_train_5dom_1k_DDOS_HOIC.npy",data_final_train)


#np.save("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/TRAIN_FINAL_CROSS_DOM_212.npy",df_train)

# %%
# data_train_balanced = pd.concat([data_normal,data_anom])
# data_train_balanced = data_train_balanced.sample(frac=1)
# data_train_balanced

# %%
# !ls -lrt

# %%
#!python /content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/multitaskAutoencoders.py

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# **BATCH = 50, DATA = 10K**

# %%
from MTAE import MultitaskAutoencoder
# Out:
# SHAPE GTR TRAIN DATA: (101903, 29)
# SHAPE TRAIN DATA: (101903, 29)
# Ytrain shape: (101903, 1)
# X_in SHAPE: (101903, 29)
# X_out SHAPE: 101903
# D_in shape: 29
# ====> Epoch: 300 Average loss: 4.1812
# ====> Epoch: 300 Average loss: 3.9951
# ====> Epoch: 300 Average loss: 3.8531
# ====> Epoch: 300 Average loss: 3.7331
# ====> Epoch: 300 Average loss: 3.6269
# ====> Epoch: 300 Average loss: 3.5365
# ====> Epoch: 300 Average loss: 3.4622
# ====> Epoch: 300 Average loss: 3.4040
# ====> Epoch: 300 Average loss: 3.3553
# ====> Epoch: 300 Average loss: 3.3129
# ====> Epoch: 300 Average loss: 3.2801
# ====> Epoch: 300 Average loss: 3.2514
# ====> Epoch: 300 Average loss: 3.2254
# ====> Epoch: 300 Average loss: 3.2040
# ====> Epoch: 300 Average loss: 3.1876
# ====> Epoch: 300 Average loss: 3.1737
# ====> Epoch: 300 Average loss: 3.1599
# ====> Epoch: 300 Average loss: 3.1464
# ====> Epoch: 300 Average loss: 3.1323
# ====> Epoch: 300 Average loss: 3.1190
# ...

# %% [markdown]
# **TESTING**

# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd

# %%
def load_data(path):

    #train_data = pd.read_csv(DATA_PATH, sep=',')
    #train_data = train_data.sample(frac = 1).reset_index(drop=True)
    train_data = path
    train_data[train_data.select_dtypes(np.float64).columns] = train_data.select_dtypes(np.float64).astype(np.float32)

    x_train = train_data.loc[:,train_data.columns != 'Label']

    x_train = torch.tensor(x_train.values)
    #x_train = x_train.values.astype['float32']

    y_train = train_data.loc[:,train_data.columns == 'Label']
    y_train = torch.tensor(y_train.values)
    y_train = y_train.long()

    print ("X train shape:", x_train.shape)
    print ("Y train shape:", y_train.shape)

    return x_train, y_train

# %%
from torch.utils.data import Dataset, DataLoader
class DataBuilder(Dataset):
    def __init__(self, path):
        #self.x, self.standardizer, self.wine = load_data(DATA_PATH)
        self.x, self.y = load_data(DATA_PATH)
        self.len=self.x.shape[0]
    def __getitem__(self,index):
        return self.x[index], self.y[index]
    def __len__(self):
        return self.len

# %%
# DATA_PATH_1 = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/test_IN_data.csv" )
# DATA_PATH_2 = pd.read_csv ("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/test_IN2_data.csv")
# DATA_PATH_3 = pd.read_csv ("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/test_IN3_data.csv")
# DATA_PATH_4 = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/test_IN4_data.csv" )
# DATA_PATH_5 = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/test_IN5_data.csv")

# %%
# test_data_final = pd.concat([DATA_PATH_1,DATA_PATH_2,DATA_PATH_3,DATA_PATH_4,DATA_PATH_5])

# %%
#DATA_PATH.to_csv('/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/BENIGN_TEST.csv', index = False)

# %%
# test_IN7_DDOS_HOIC = pd.read_csv ("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/test_IN7_DDOS_HOIC.csv")

# test_IN7_DDOS_HOIC.loc[ test_IN7_DDOS_HOIC['Label'] == 2.0, 'Label'] = 1.0
# test_IN7_DDOS_HOIC.loc[ test_IN7_DDOS_HOIC['Label'] == 3.0, 'Label'] = 1.0

# test_IN7_DDOS_HOIC.to_csv('/content/gdrive/MyDrive/OOD_generalization/mate-master_old/test_IN7_DDOS_HOIC.csv', index = False)

# %%
# test_OOD_RARE = pd.read_csv ("/content/gdrive/MyDrive/OOD_generalization/mate-master_old/test_OOD_RARE.csv")

# test_OOD_RARE.loc[ test_OOD_RARE['Label'] == 2.0, 'Label'] = 1.0
# test_OOD_RARE.loc[ test_OOD_RARE['Label'] == 3.0, 'Label'] = 1.0

# test_OOD_RARE.to_csv('/content/gdrive/MyDrive/OOD_generalization/mate-master_old/test_OOD_RARE.csv', index = False)

# %% [markdown]
# **OOD DATA**

# %%
data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/RARE.csv")
#data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/TEST_BOT.csv")
#data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/TEST_INFIL.csv")
#data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/TEST_GOLDEN_EYE.csv")
#data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/TEST_SOLARIS.csv")
#data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/BENIGN_1.csv")
#data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/FTP_BRUT.csv")
#data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/SSH_BRUT.csv")
#data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/TEST_HULK.csv")
#data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/TEST_UDP.csv")
#data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/TEST_HOIC.csv")

#data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/TRAIN_FINAL_CROSS_DOM_3K.csv")


# data_bot.loc[ data_bot['Label'] == 2.0, 'Label'] = 1.0
# data_bot.loc[ data_bot['Label'] == 3.0, 'Label'] = 1.0

#data_bot = data_bot.loc[data_bot['Label'] == 0]
DATA_PATH = data_bot
#DATA_PATH
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-10-a5252d2e8d61>", line 1, in <cell line: 1>
#     data_bot = pd.read_csv("/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/DATA_2/RARE.csv")
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
# ...

# %%
data_set=DataBuilder(DATA_PATH)
testloader=DataLoader(dataset=data_set,batch_size=1)

D_in = 29
print ("D_in shape:", D_in)
H = 25
H2 = 20
# Out:
# X train shape: torch.Size([2000, 29])
# Y train shape: torch.Size([2000, 1])
# D_in shape: 29

# %%
#PATH = "/content/gdrive/MyDrive/OOD_generalization/mate-master_old/meta_latent_model_4cl.pth" ## best meta model

PATH = "/content/gdrive/MyDrive/OOD_generalization/mate-mi-reg-model/meta_latent_MTAE_17K.pth"  ## 700

#meta_latent_model_15K_REC06_MI2.pth
#meta_latent_model_15K_REC06_MI2_btch25
#meta_latent_model_MI_V100_CROSS_DOM_21K_b100
#meta_latent_model_MI_V100_CROSS_DOM_21K
#meta_latent_model_MI_V100_CROSS_DOM_14K_LS_REG
#meta_latent_model_MI_V100_CROSS_DOM.pth"
#meta_latent_model_MI_V100.pth" #V12 on IN3 (Best) #V14 on OOD with MI

# %%
model_test = MultitaskAutoencoder(D_in, H, H2)#.to(device)
map_location=torch.device('cpu')
model_test.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %%
correct = 0
total = 0
predict_lst = []
labels_lst = []

# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    model_test.eval()
    for data in testloader:
        X_test, labels = data
        # calculate outputs by running images through the network
        logits, recon_batch, Z = model_test(X_test)#.to(device)
        #print ("logits:", logits)

        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(logits.data, 1)
        predict_lst.append(predicted.cpu().detach().numpy())
        #predicted = torch.argmax(logits)

        labels_lst.append(labels[0].cpu().detach().numpy())

        #print("out:", _)

        print ("PREDICTED:", predicted)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of the network on the test images: {100 * correct / total} %')
# Out:
# PREDICTED: tensor([0])
# PREDICTED: tensor([1])
# PREDICTED: tensor([1])
# PREDICTED: tensor([1])
# PREDICTED: tensor([1])
# PREDICTED: tensor([1])
# PREDICTED: tensor([0])
# PREDICTED: tensor([1])
# PREDICTED: tensor([0])
# PREDICTED: tensor([1])
# PREDICTED: tensor([0])
# PREDICTED: tensor([1])
# PREDICTED: tensor([0])
# PREDICTED: tensor([1])
# PREDICTED: tensor([0])
# PREDICTED: tensor([1])
# PREDICTED: tensor([0])
# PREDICTED: tensor([0])
# PREDICTED: tensor([0])
# PREDICTED: tensor([0])
# PREDICTED: tensor([1])
# PREDICTED: tensor([0])
# PREDICTED: tensor([0])
# PREDICTED: tensor([1])
# PREDICTED: tensor([1])
# PREDICTED: tensor([1])
# PREDICTED: tensor([0])
# PREDICTED: tensor([1])
# PREDICTED: tensor([1])
# PREDICTED: tensor([1])
# PREDICTED: tensor([0])
# PREDICTED: tensor([0])
# PREDICTED: tensor([0])
# PREDICTED: tensor([0])
# PREDICTED: tensor([0])
# PREDICTED: tensor([0])
# PREDICTED: tensor([0])
# PREDICTED: tensor([0])
# PREDICTED: tensor([0])
# PREDICTED: tensor([1])
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.offline as pyo

# %%
DATA_PATH = "/content/gdrive/MyDrive/OOD_generalization/mate-master_old/test_OOD2_data.csv"  #test_data_final_CNN_20k


data_set=DataBuilder(DATA_PATH)
testloader=DataLoader(dataset=data_set,batch_size=1)

# %% [markdown]
# **OOD**

# %%
## MI = 4, REC = 0.9

import numpy as np
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import roc_auc_score


print (precision_recall_fscore_support(labels_lst, predict_lst, average='weighted'))
print (roc_auc_score(labels_lst, predict_lst))

#Accuracy of the network on the test images: 72.8 %
# Out:
# (0.6374006603255092, 0.637, 0.6367351799461808, None)
# 0.6369999999999999

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support


precision_recall_fscore_support(labels_lst, predict_lst, average='weighted')

#Accuracy of the network on the test images: 12.7 % %
# Out:
# (0.10379675304534774, 0.127, 0.11402849113876264, None)

# %% [markdown]
# MI =0, rec 0.95

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support


precision_recall_fscore_support(labels_lst, predict_lst, average='weighted')

#Accuracy of the network on the test images: 20.1% %
# Out:
# (0.2542727962551683, 0.21978021978021978, 0.23394279789113445, None)

# %% [markdown]
# **IN**

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support


precision_recall_fscore_support(labels_lst, predict_lst, average='weighted')

#Accuracy of the network on the test images: 80 %
# Out:
# (0.8832886163280951, 0.84775, 0.844137087957421, None)

# %% [markdown]
# MI = 0, rec = 0.95

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support


precision_recall_fscore_support(labels_lst, predict_lst, average='weighted')

#Accuracy of the network on the test images: 61.3 %
# Out:
# (0.6386332965280334, 0.613, 0.5942439254541165, None)

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support


precision_recall_fscore_support(labels_lst, predict_lst, average='weighted')

#Accuracy of the network on the test images: 80 %
# Out:
# (0.8839906073082862, 0.882, 0.8818468735481183, None)

# %% [markdown]
# **with MI**

# %% [markdown]
# **OOD**

# %% [markdown]
# entropy = 0.9, L2 = 0.5

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support


precision_recall_fscore_support(labels_lst, predict_lst, average='weighted')

#Accuracy of the network on the test images: 63.2 % %
# Out:
# (0.7880184331797235, 0.632, 0.5743578355170627, None)

# %% [markdown]
# entropy = 0.0, L2 = 0.9

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support


precision_recall_fscore_support(labels_lst, predict_lst, average='weighted')

#Accuracy of the network on the test images: 59 % %
# Out:
# (0.6636904761904762, 0.588, 0.5341474445952058, None)

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support


precision_recall_fscore_support(labels_lst, predict_lst, average='weighted')

#Accuracy of the network on the test images: 74 %
# Out:
# (0.7751269198637619, 0.774, 0.7737683387789096, None)

# %% [markdown]
# **IN**

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support


precision_recall_fscore_support(labels_lst, predict_lst, average='weighted')

#Accuracy of the network on the test images: 77 %
# Out:
# (0.7751269198637619, 0.774, 0.7737683387789096, None)

# %%
## MI = 4, REC = 0.9

import numpy as np
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import roc_auc_score


print (precision_recall_fscore_support(labels_lst, predict_lst, average='weighted'))
print (roc_auc_score(labels_lst, predict_lst))

#Accuracy of the network on the test images: 72.8 %
# Out:
# (0.410701391000304, 0.5884615384615385, 0.4778695175135305, None)
# 0.46017857142857144

# %%
#entropy = 0.9, L2 = 0.2

import numpy as np
from sklearn.metrics import precision_recall_fscore_support


precision_recall_fscore_support(labels_lst, predict_lst, average='weighted')

#Accuracy of the network on the test images: 94.5 %
# Out:
# (0.9460071361141779, 0.946, 0.9459997839991359, None)

# %% [markdown]
# entropy = 0.0, L2 = 0.9

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support


precision_recall_fscore_support(labels_lst, predict_lst, average='weighted')

#Accuracy of the network on the test images: 77 %
# Out:
# (0.6950290825751115, 0.693, 0.6921994106671452, None)

# %%
import numpy as np
from sklearn.metrics import precision_recall_fscore_support


precision_recall_fscore_support(labels_lst, predict_lst, average='weighted')

#Accuracy of the network on the test images: 47.6 %
# Out:
# (0.4743168276145469, 0.476, 0.46727178085757043, None)
